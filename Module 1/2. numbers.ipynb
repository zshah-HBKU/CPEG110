# %% [markdown]
# # [Numbers](https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex)

# %% [markdown]
# ## `int`

# %%
my_int = 6
print('value: {}, type: {}'.format(my_int, type(my_int)))
# Out:
# value: 6, type: <class 'int'>

# %%
my_int = -60
print('value: {}, type: {}'.format(my_int, type(my_int)))
# Out:
# value: -60, type: <class 'int'>

# %% [markdown]
# ## `float`

# %%
my_float = 10.5
print('value: {}, type: {}'.format(my_float, type(my_float)))
# Out:
# value: 10.5, type: <class 'float'>

# %%
my_float = -16.2
print('value: {}, type: {}'.format(my_float, type(my_float)))
# Out:
# value: -16.2, type: <class 'float'>

# %%
my_var = 80.56
type(my_var)
# Out:
# float

# %% [markdown]
# Note that division of `int`s produces `float`:

# %%
print(1 / 1)
print(6 / 5)
# Out:
# 1.0
# 1.2

# %% [markdown]
# Be aware of the floating-point pitfalls (see [Decimal](#decimal) for workaround):

# %%
val = 0.1 + 0.1 + 0.1
print(val == 0.3)
print(val)
# Out:
# False
# 0.30000000000000004

# %% [markdown]
# ## Floor division `//`, modulus `%`, power `**` and more

# %%
7 + 5
# Out:
# 12

# %%
7 - 5
# Out:
# 2

# %%
7 / 5
# Out:
# 1.4

# %%
7 * 5
# Out:
# 35

# %%
7 // 5
# Out:
# 1

# %%
7 % 5
# Out:
# 2

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# ## `abs(), int(), float(), complex(), divmod(), power()`

# %%
abs(-5)
# Out:
# 5

# %%
int(1.92)
# Out:
# 1

# %%
int('1')
# Out:
# 1

# %%
float(1)
# Out:
# 1.0

# %%
float('1.92')
# Out:
# 1.92

# %%
complex(5,2)
# Out:
# (5+2j)

# %%
divmod(7,5)# 7%5
# Out:
# (1, 2)

# %%
pow(7,5)# 7 ** 5
# Out:
# 16807

# %%
f = 0.1
print(f)
# Out:
# 0.1

# %% [markdown]
# <a id='decimal'></a>
# ## [`decimal.Decimal`](https://docs.python.org/3/library/decimal.html)

# %%
from decimal import Decimal

# %%
from_float = Decimal(0.1)
from_str = Decimal('0.1')
print('from float: {}\nfrom string: {}'.format(from_float, from_str))
# Out:
# from float: 0.1000000000000000055511151231257827021181583404541015625
# from string: 0.1

# %%
val = 0.1 + 0.1 + 0.1
print(val == 0.3)
print(val)
# Out:
# False
# 0.30000000000000004

# %%
my_decimal = Decimal('0.1')
sum_of_decimals = my_decimal + my_decimal + my_decimal
print(sum_of_decimals == Decimal('0.3'))
# Out:
# True

# %% [markdown]
# ## Operator precedence in calculations
# Mathematical operator precedence applies. Use brackets if you want to change the execution order:

# %%
print(1 + 2**2 * 3 / 6) # 1 + 4 * 3 / 6 == 1 + 12 / 6 == 1 + 2
print((1 + 2**2) * 3 / 6) # (1+4)*3/6 = 5*3/6 = 15/6
# Out:
# 3.0
# 2.5

# %%
print(1 + 2**2 * 3 / 6)
